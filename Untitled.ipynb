# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv('data/GUIDE_Train.csv')

# %%
train.head(5)
# Out:
#                                                                                                                                                                                                                                                                                                                                                   oThreatsFound  \
# 481036341936  138  53890  761322 2024-06-10T16:06:16.000Z 138.0 119.0 Execution          T1059.001       TruePositive   NaN NaN Process Related  98799.0 81.0     360606.0 160396.0 441377.0 673934.0 425863.0 453297.0 153085.0 529644.0 NaN 1631.0 635.0 860.0 2251.0 3421.0 881.0 NaN 5.0      79.0     3586.0 NaN NaN 5.0 66.0 NaN Suspicious    Suspicious
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 135760 entries, (481036341936, 138, 53890, 761322, '2024-06-10T16:06:16.000Z', 138.0, 119.0, 'Execution', 'T1059.001', 'TruePositive', nan, nan, 'Process', 'Related', 98799.0, 81.0, 360606.0, 160396.0, 441377.0, 673934.0, 425863.0, 453297.0, 153085.0, 529644.0, nan, 1631.0, 635.0, 860.0, 2251.0, 3421.0, 881.0, nan, 5.0, 79.0, 3586.0, nan, nan, 5.0, 66.0, nan, 'Suspicious') to (377957126471, 386, 14326, 15851, '2024-06-03T11:50', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan)
# Data columns (total 4 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   oThreatsFound  31813 non-null   object
#  1   242            135759 non-null  float64
#  2   1445           135759 non-null  float64
#  3   10630          135759 non-null  float64
# ...

# %%
test = pd.read_csv('data/GUIDE_Test.csv')

# %%
test.head(5)
# Out:
#               Id  OrgId  IncidentId  AlertId                 Timestamp  \
# 0  1245540519230    657       11767    87199  2024-06-04T22:56:27.000Z
# 1  1400159342154      3       91158   632273  2024-06-03T12:58:26.000Z
# 2  1279900255923    145       32247   131719  2024-06-08T03:20:49.000Z
# 3    60129547292    222       15294   917686  2024-06-12T12:07:31.000Z
# 4   515396080539    363        7615     5944  2024-06-06T17:42:05.000Z
#
#    DetectorId  AlertTitle           Category                  MitreTechniques  \
# 0         524         563    LateralMovement      T1021;T1047;T1105;T1569.002
# 1           2           2  CommandAndControl                              NaN
# 2        2932       10807    LateralMovement  T1021;T1027.002;T1027.005;T1105
# 3           0           0      InitialAccess                  T1078;T1078.004
# 4          27          18          Discovery                  T1087;T1087.002
#
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 291857 entries, 0 to 291856
# Data columns (total 46 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Id                  291857 non-null  int64
#  1   OrgId               291857 non-null  int64
#  2   IncidentId          291857 non-null  int64
#  3   AlertId             291857 non-null  int64
#  4   Timestamp           291857 non-null  object
#  5   DetectorId          291857 non-null  int64
#  6   AlertTitle          291857 non-null  int64
#  7   Category            291857 non-null  object
#  8   MitreTechniques     129240 non-null  object
#  9   IncidentGrade       291857 non-null  object
#  10  ActionGrouped       149 non-null     object
#  11  ActionGranular      149 non-null     object
#  12  EntityType          291857 non-null  object
#  13  EvidenceRole        291857 non-null  object
#  14  DeviceId            291857 non-null  int64
# ...
